# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset=pd.read_csv("/content/drive/MyDrive/project files/finalfile.csv")
print(dataset)
arr1 = np.array(dataset['x'])
arr2 = np.array(dataset['y'])

print(arr1)
print(arr2)
# Out:
#                x         y  z  fault
# 0      -0.402027 -0.058965  0      1
# 1       0.548219  0.221480  0      1
# 2       0.931565  0.044173  0      1
# 3      -0.218881 -0.017669  0      1
# 4      -1.079788  0.187580  0      1
# ...          ...       ... ..    ...
# 121152 -0.042349  0.098824  0      0
# 121153 -0.013560  0.042940  0      0
# 121154  0.057369  0.024655  0      0
# 121155  0.095129  0.000205  0      0
# 121156  0.062793  0.026709  0      0
#
# [121157 rows x 4 columns]
# [-0.40202695  0.54821856  0.93156547 ...  0.05736923  0.09512861
#   0.06279323]
# [-5.8965455e-02  2.2148000e-01  4.4172727e-02 ...  2.4654545e-02
#   2.0545500e-04  2.6709091e-02]

# %%
plt.plot(dataset['x'])
plt.show()
plt.plot(dataset['y'])
plt.show()
faulty_img = '/content/drive/MyDrive/project files/Faulty_Images/'
normal_img = '/content/drive/MyDrive/project files/Normal_Images/'

for i in range(0, 2000, 20):
  plt.plot(arr1[i:i+20])
  fig1 = plt.gcf()
  fig1.savefig(f"{faulty_img}/{i}.png")
  plt.show()
  # plt.draw()
# for i in range()
#   plt.plot(arr2[i:i+20])
#   plt.show()
#   plt.savefig(f"{faulty_img}/{i}.png")

# %%
# # Assuming dataset is your pandas DataFrame containing the vibration data
# # and 'DE' and 'FE' are the columns representing the vibration data

# # Assuming dataset is your pandas DataFrame containing the vibration data
# # and 'DE' and 'FE' are the columns representing the vibration data

# # Step 1: Pre-processing
# # Ensure data is properly formatted and sampled
# # Remove noise/outliers and filter data if necessary

# # Step 2: Calculate RMS
# # Assuming dataset['DE'] and dataset['FE'] represent vibration data
# # Calculate RMS for 'DE' and 'FE' columns
# rms_de = np.sqrt(np.mean(dataset['DE']**2))
# rms_fe = np.sqrt(np.mean(dataset['FE']**2))

# # Step 3: Determine threshold for failure data
# # You can set a threshold based on the RMS values
# threshold = 0.5 * (rms_de + rms_fe)  # Example threshold, you can adjust as needed

# # Step 4: Plot the data
# plt.plot(dataset['DE'], label='DE', )  # Plot DE data
# plt.plot(dataset['FE'], label='FE')  # Plot FE data

# # Plot horizontal line for threshold
# plt.axhline(y=threshold, color='r', linestyle='--', label='Threshold')

# # Highlight failure data (above threshold)
# plt.fill_between(dataset.index, dataset['DE'], dataset['FE'], where=(dataset['DE'] > threshold) | (dataset['FE'] > threshold), color='red', alpha=0.3, label='Failure Data')

# # Highlight normal data (below threshold)
# plt.fill_between(dataset.index, dataset['DE'], dataset['FE'], where=(dataset['DE'] <= threshold) & (dataset['FE'] <= threshold), color='green', alpha=0.3, label='Normal Data')

# # Add labels, title, and legend
# plt.xlabel('Time')
# plt.ylabel('Amplitude')
# plt.title('Vibration Data Analysis')
# plt.legend()

# # Show the plot
# plt.show()
# plt.plot(dataset['DE'])
# plt.show()
# plt.plot(dataset['FE'])
# plt.show()
